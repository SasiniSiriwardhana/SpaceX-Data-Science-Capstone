# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from io import StringIO

url = "https://en.wikipedia.org/wiki/List_of_Falcon_9_and_Falcon_Heavy_launches"

headers = {'User-Agent': 'Mozilla/5.0'}
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

all_tables = soup.find_all('table')
print(f"Found {len(all_tables)} tables")

if len(all_tables) > 2:
    df = pd.read_html(StringIO(str(all_tables[2])))[0]
    df.to_csv('spacex_web_scraped.csv', index=False)
    print(df.head())
else:
    print("Check connection or URL")
# Out:
# Found 15 tables
#    Flight No.                                Date and time (UTC)  \
# 0         583                         January 3, 2026 02:09[473]
# 1         583       Third COSMO-SkyMed 2nd-generation satellite.
# 2         584                         January 4, 2026 06:48[474]
# 3         584  Launch of 29 Starlink v2 mini optimized satell...
# 4         585                         January 9, 2026 21:41[475]
#
#                                  Version, booster[j]  \
# 0                                     F9 B5 B1081‑21
# 1       Third COSMO-SkyMed 2nd-generation satellite.
# 2                                      F9 B5 B1101‑1
# 3  Launch of 29 Starlink v2 mini optimized satell...
# 4                                     F9 B5 B1069‑29
#
#                                          Launch site  \
# 0                                 Vandenberg, SLC‑4E
# 1       Third COSMO-SkyMed 2nd-generation satellite.
# 2                             Cape Canaveral, SLC‑40
# 3  Launch of 29 Starlink v2 mini optimized satell...
# 4                             Cape Canaveral, SLC‑40
#
#                                           Payload[k]  \
# 0                                              CSG-3
# 1       Third COSMO-SkyMed 2nd-generation satellite.
# 2                               Starlink: Group 6-88
# 3  Launch of 29 Starlink v2 mini optimized satell...
# 4                               Starlink: Group 6-96
#
#                                         Payload mass  \
# 0                                2,230 kg (4,920 lb)
# 1       Third COSMO-SkyMed 2nd-generation satellite.
# 2                             ~16,675 kg (36,762 lb)
# 3  Launch of 29 Starlink v2 mini optimized satell...
# 4                             ~16,675 kg (36,762 lb)
#
#                                                Orbit  \
# 0                                                SSO
# 1       Third COSMO-SkyMed 2nd-generation satellite.
# 2                                                LEO
# 3  Launch of 29 Starlink v2 mini optimized satell...
# 4                                                LEO
#
#                                             Customer  \
# 0                                                ASI
# 1       Third COSMO-SkyMed 2nd-generation satellite.
# 2                                             SpaceX
# 3  Launch of 29 Starlink v2 mini optimized satell...
# 4                                             SpaceX
#
#                                       Launch outcome  \
# 0                                            Success
# 1       Third COSMO-SkyMed 2nd-generation satellite.
# 2                                            Success
# 3  Launch of 29 Starlink v2 mini optimized satell...
# 4                                            Success
#
#                                      Booster landing
# 0                                     Success (LZ‑4)
# 1       Third COSMO-SkyMed 2nd-generation satellite.
# 2                                     Success (JRTI)
# 3  Launch of 29 Starlink v2 mini optimized satell...
# 4                                     Success (ASOG)
